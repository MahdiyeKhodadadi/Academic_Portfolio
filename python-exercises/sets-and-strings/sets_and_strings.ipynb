# %%
# -*- coding: utf-8 -*-
"""hooshatech_datascience1_section2(Set &History).ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1oZZHZSU7x6ti2Xq2GO4ciUO_R8nMCHP4

setمجموعه ها
"""

set4={ "hello",546464   ,False   ,6   ,"g" }
print(set4)
print(type(set4))

set1 = {"hooshatech", 34, True, 40, "noyangostarfartakhooshmand"}

print(set1)

a ={"apple", "banana", "cherry", "apple"}
print(a)

"""نکته: متدها و توابع در پایتون با علامت () نمایش داده میشود"""

b=set()
b.add(4)
b.add(14)
b.add(40)
b.add(23)
b

list1=[1,2,3,4,5,6,7]
c=set(list1)
print(type(list1))
print(type(c))

list1=[1,23,45,1,1,1,1,1,1,2,3,4,5,6,7]
D=set(list1)
D

set2={1, 2, 3,5,5,5,5, 4, 5, 6, 7, 23, 45}
set2

list1=[1,23,45,1,1,1,1,1,1,2,3,4,5,6,7]
e=set(list1)
print(e)
print(list(e))

print(list(set(e)))

e



e.clear()
e

set1 = {"python", "java", "c++"}
set2 = {34, 6, 89, 999, 23}
set3 = {True, False, False}

print(set1)
print(set2)
print(set3)

s=set1.discard(2)
s

s=set1.discard(34)
s

set1.add(54)
set1.remove(54)
set1.pop()
set1

"""**Access Set Items**"""

thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)

""")متدهای مجموعه ها  **set methods**
Method	Description

add()
Adds an element to the set

clear()
Removes all the elements from the set

copy()
Returns a copy of the set

difference()
Returns a set containing the difference between two or more sets


difference_update()
Removes the items in this set that are also included in another, specified set

discard()
Remove the specified item

intersection()
Returns a set, that is the intersection of two other sets

intersection_update()
Removes the items in this set that are not present in other, specified set(s)

isdisjoint()
Returns whether two sets have a intersection or not

issubset()
Returns whether another set contains this set or not

issuperset()
Returns whether this set contains another set or not

pop()
Removes an element from the set

remove()
Removes the specified element

symmetric_difference()
Returns a set with the symmetric differences of two sets

symmetric_difference_update()	inserts the symmetric differences from this set and another
union()	Return a set containing the union of sets
update()	Update the set with the union of this set and others
"""

set1.add(4)
set1.clear()
set1.copy()
set1.difference({1,3})
set1.difference_update({1,3})
set1.discard(4)
set1.intersection({1,3})
set1.intersection_update({2,3})
set1.isdisjoint(({3,4}))
set1.issubset({1,2,3,4})
set1.issuperset({1})
set1.pop()
set1.remove(34)
set1.symmetric_difference({2,3})
set1.symmetric_difference_update({2,3})
set1.union({6,7,8})
set1.update({5,6})



#{1,2}.add(3)
#{1,2}.clear()
#{1,2}.copy()
#{1,2}.difference({1,3})
#{1,2}.difference_update({1,3})
#{1,2}.discard(2)
#{1,2}.intersection({1,3})
#{1,2}.intersection_update({1,3})
#{1,2}.isdisjoint(({3,4}))
#{1,2}.issubset({1,3,2})
#{1,2}.issubset({1})
#{1,2}.pop()
#{1,2}.remove(2)
#{1,2}.symmetric_difference({2,3})
#{1,2}.symmetric_difference_update({2,3})
#{1,2}.union({2,3})
#{1,2}.update({2,3})

"""**set progress**"""

#ست ها ترتیب ندارند و ایندکس گذاری ندارند ولی تکراری اضافه نمیکنند
myset=set()
myset.add(2)
myset.add(3)
myset.add(2)
myset.add(4)
myset.add(3)
myset

s=set()
s

s.add(561111)
s.add(561)
s.add(5611)
s.add(560)
s

s.difference(myset)

set3 = {"hooshatec", "noyan", "gostar"}
hooshatech1 = {"pineapple", "mango", "papaya"}

set3.update(hooshatech1)

print(set3)

set4 = {"hooshatec", "noyan", "gostar"}
hooshatech2 = ["fartak", "zaghari"]

set4.update(hooshatech2)

print(set4)

#Note: If the item to remove does not exist, remove() will raise an error.
set5 = {"hooshatec", "noyan", "gostar"}
hooshatech3 = ["fartak", "zaghari"]
set5.remove("noyan")
print(set5)

#Note: If the item to remove does not exist, discard() will NOT raise an error.
set6 = {"hooshatec", "noyan", "gostar"}
hooshatech4 = ["fartak", "zaghari"]
set6.discard("noyan")
print(set6)

#this method will remove a random item
set7 = {"hooshatec", "noyan", "gostar"}
hooshatech5 = ["fartak", "zaghari"]
x = set7.pop()
print(x)
print(set7)

set8 = {"hooshatec", "noyan", "gostar"}
hooshatech6 = ["fartak", "zaghari"]
x = set8.clear()
print(x)
print(set8)

#The del keyword will delete the set completely:
set9 = {"hooshatec", "noyan", "gostar"}
hooshatech6 = ["fartak", "zaghari"]
del set9
print(set9)

set10 = {"hooshatec", "noyan", "gostar"}
hooshatech7 = ["fartak", "zaghari"]
for x in set10:
  print(x)

set11 = {"a", "b" , "c"}
set12 = {1, 2, 3}

set13 = set11.union(set12)
print(set13)

#Keep the items that exist in both set set14, and set hooshatech8:
set14 = {"hooshatec", "noyan", "gostar"}
hooshatech8 = ["fartak", "zaghari","hooshatec"]
set14.intersection_update(hooshatech8)
print(set14)

#The intersection() method will return a new set, that only contains the items that are present in both sets.
set15 = {"hooshatec", "noyan", "gostar"}
hooshatech9 = ["fartak", "zaghari"]
set15.intersection(hooshatech9)
print(set15)

#The symmetric_difference_update() method will keep only the elements that are NOT present in both sets.
set16 = {"hooshatec", "noyan", "gostar"}
hooshatech10 = ["fartak", "zaghari","hooshatec", "noyan", "gostar"]
set16.symmetric_difference_update(hooshatech10)
print(set16)

#The symmetric_difference() method will return a new set, that contains only the elements that are NOT present in both sets.
set17 = {"hooshatec", "noyan", "gostar"}
hooshatech11 = ["fartak", "zaghari","hooshatec", "noyan", "gostar"]
set17.symmetric_difference_update(hooshatech11)
print(set17)

"""**stringsرشته** """

string_var="noyan gostar fartak hooshmand zaghari"
name="noyan gostar fartak hooshmand zaghari $$#@@%&I)P!!# "
name2="SDTFGYUHJIKL ;WERTYUH     L;SDFG   HJKMXVG   HJKGFUK "

"""scape characters"""

scape1="noyan gostar \nfartak hooshmand \tzaghari"
scape1

print(scape1)

len(scape1)

"""**modify methods & Properties**"""

name="noyan gostar fartak hooshmand zaghari $$#@@%&I)P!!# "
name.upper()

# متد زیر کل رشته را با حروف بزرگ نمایش میدهد
print("name base is : " , name)
a=name.upper()
print("name uppermethod is : " , a)

# متد زیر کل رشته را با حروف کوچک نمایش میدهد
name3= "NOYAN GOSTAR FARTAK HOOSHMAND ZAGHARI $$#@@%&I)P!!#"
print(name3)
print(name3.lower())

name.replace("f" ,"z")

#   ومتد زیر کل رشته را جدا میکند و بصورت لیست بصورت پیشرفت براساس اسپیس نمایش میدهد ولی میتوان به آن براساس انتخاب جدا کند
name.split("a")

name2="noyan , gostar , fartak , hoosh , mand , zaghari , $$#@@,%&I)P!!# "
print(name.split(","))

a= "hello , world"
print(a.split(","))

#فقط حرف اول رشته را بزرگ میکند
name.capitalize()

#پیدا کردن تعداد یک حرف  و موقعیت آن
print(name.count("a"))
print(name.find("a"))
#print(name.index(3))

#تعدادش 25 کاراکتر بیشتر نشود و اول و آخرش یک کاراکتر بزند
name5="salamscnhs,dnsdvsbv nm  sdvbdfsbsbj bv hbhdmbvjbdb "
name5.center(100,'_')

"hooshatech\tnoyangostar"

"hooshatech\tnoyangostar".expandtabs()

name.islower()

name.isalnum()

name.isalpha()

"hooshatech\tnoyangostar".isupper()

name.endswith("d")

n6="hooshatech\tnoyangostar"
n6[5]=="o"

#اولین او را جدا میکنه خود او را هم نشان میدهد
n7="yjghjhgjhgoyoyoyoyoyoyoyoyoy"
n7.partition('o')

name2="SDTFGYUHJIKL ;WERTYUH     L;SDFG   HJKMXVG   HJKGFUK "
#name2.upper()
name2.casefold()

"""**string indexing & slicing**"""

scape1="noyan gostar \nfartak hooshmand \tzaghari"
print(scape1[6])
print(scape1[-1])
print(scape1[ : : -1])

name="noyan gostar fartak hooshmand zaghari $$#@@%&I)P!!# "
#     0123456789101112131415161718
print(name[2 :10 :2])
print(name[-5 :-2])

# immutable means no change
name="noyan gostar fartak hooshmand zaghari $$#@@%&I)P!!# "
name[0]="h"

#mutable with concateniation
name_concat="h" +name[1:]
name_concat

#dynamic typing
"2" +1

"""**print formating**"""

name3="noyan gostar fartak hooshmand Nasrin zaghari  "
#string interpolation
print(name3 +"hooshatech")

"""اضافه کردن یک چیزی به داخل این دابل کوتیشن"""

#place holder   {}
print( " hooshatech compony name is {} forever ".format("zanbil"))

print( " hooshatech {} compony name is {} forever ".format("AI" ,"noyan gostr"))

#place holder indexing
print( " hooshatech {1} compony name is {0} forever ".format("AI" ,"noyan gostr"))

print( " hooshatech {pl2} compony name is {pl1} forever ".format(pl1="AI" ,pl2="noyan gostr"))

pl3="zaghariicompany"
pl4="datascience"
print( " hooshatech {} compony name is {} forever ".format(pl3,pl4))

#f formating string
name6="nasrin"
print( f" hooshatech {name6} compony name is {pl4} forever ")

"""**String progress**"""
